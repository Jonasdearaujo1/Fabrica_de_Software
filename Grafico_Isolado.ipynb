# %%
import pandas as pd

dollar = pd.read_csv('dolar.csv')#Arquivo buscado, Ronaldo.csv

display(dollar)
# Out:
#         data dolar_fechamento
# 0    2010-01           1,6930
# 1    2010-02           1,8190
# 2    2010-03           1,7563
# 3    2010-04           1,7302
# 4    2010-05           1,6760
# ..       ...              ...
# 143  2021-12           5,6209
# 144  2022-01           5,5693
# 145  2022-02           5,3031
# 146  2022-03           5,1589
# 147  2022-04           4,7378
#
# [148 rows x 2 columns]

# %%
import plotly.express as px
grafico = px.line(dollar, x = 'data', y = 'dolar_fechamento')
grafico.show()
# Out:
# <div>                            <div id="8a98871d-6eab-410b-a323-0962af03f58d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a98871d-6eab-410b-a323-0962af03f58d")) {                    Plotly.newPlot(                        "8a98871d-6eab-410b-a323-0962af03f58d",                        [{"hovertemplate":"data=%{x}<br>dolar_fechamento=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2010-01","2010-02","2010-03","2010-04","2010-05","2010-06","2010-07","2010-08","2010-09","2010-10","2010-11","2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12","20
# ...
